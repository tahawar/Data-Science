# %% [markdown]
# 1- Load the file IMDB-Movie-Data.csv in pandas and make title as index column

# %%
import pandas as pd
movies_df = pd.read_csv("IMDB-Movie-Data.csv", index_col="Title")

# %%
movies_df.head()
# Out:
#                          Rank                     Genre  \
# Title
# Guardians of the Galaxy     1   Action,Adventure,Sci-Fi
# Prometheus                  2  Adventure,Mystery,Sci-Fi
# Split                       3           Horror,Thriller
# Sing                        4   Animation,Comedy,Family
# Suicide Squad               5  Action,Adventure,Fantasy
#
#                                                                Description  \
# Title
# Guardians of the Galaxy  A group of intergalactic criminals are forced ...
# Prometheus               Following clues to the origin of mankind, a te...
# Split                    Three girls are kidnapped by a man with a diag...
# Sing                     In a city of humanoid animals, a hustling thea...
# Suicide Squad            A secret government agency recruits some of th...
#
#                                      Director  \
# Title
# Guardians of the Galaxy            James Gunn
# Prometheus                       Ridley Scott
# ...

# %% [markdown]
# 2 Display 5 most repeated values in Director Column

# %%
value_counts = movies_df['Director'].value_counts()
value_counts.head()
# Out:
# Ridley Scott          8
# David Yates           6
# M. Night Shyamalan    6
# Paul W.S. Anderson    6
# Michael Bay           6
# Name: Director, dtype: int64

# %% [markdown]
# 3- Filter all movies from Passengers to Gold using value (loc)

# %%
movies_df.loc['Passengers': 'Gold']
# Out:
#                                          Rank                       Genre  \
# Title
# Passengers                                 10     Adventure,Drama,Romance
# Fantastic Beasts and Where to Find Them    11    Adventure,Family,Fantasy
# Hidden Figures                             12     Biography,Drama,History
# Rogue One                                  13     Action,Adventure,Sci-Fi
# Moana                                      14  Animation,Adventure,Comedy
# Colossal                                   15         Action,Comedy,Drama
# The Secret Life of Pets                    16  Animation,Adventure,Comedy
# Hacksaw Ridge                              17     Biography,Drama,History
# Jason Bourne                               18             Action,Thriller
# Lion                                       19             Biography,Drama
# Arrival                                    20        Drama,Mystery,Sci-Fi
# Gold                                       21    Adventure,Drama,Thriller
# ...

# %% [markdown]
# 4- Filter all movies from Passengers to Gold using position (iloc)

# %%
movies_df.iloc[movies_df.index.get_loc('Passengers'): movies_df.index.get_loc('Gold')]
# Out:
#                                          Rank                       Genre  \
# Title
# Passengers                                 10     Adventure,Drama,Romance
# Fantastic Beasts and Where to Find Them    11    Adventure,Family,Fantasy
# Hidden Figures                             12     Biography,Drama,History
# Rogue One                                  13     Action,Adventure,Sci-Fi
# Moana                                      14  Animation,Adventure,Comedy
# Colossal                                   15         Action,Comedy,Drama
# The Secret Life of Pets                    16  Animation,Adventure,Comedy
# Hacksaw Ridge                              17     Biography,Drama,History
# Jason Bourne                               18             Action,Thriller
# Lion                                       19             Biography,Drama
# Arrival                                    20        Drama,Mystery,Sci-Fi
#
# ...

# %% [markdown]
# 5- List all movies from year 2012

# %%
movies = movies_df.loc[movies_df['Year'] == 2012]
movies
# Out:
#                             Rank                      Genre  \
# Title
# Prometheus                     2   Adventure,Mystery,Sci-Fi
# The Avengers                  77              Action,Sci-Fi
# The Dark Knight Rises        125            Action,Thriller
# The Place Beyond the Pines   136       Crime,Drama,Thriller
# Django Unchained             145              Drama,Western
# ...                          ...                        ...
# The Expendables 2            917  Action,Adventure,Thriller
# The Master                   930                      Drama
# End of Watch                 958       Crime,Drama,Thriller
# Rock of Ages                 973       Comedy,Drama,Musical
# Project X                    995                     Comedy
#
#                                                                   Description  \
# Title
# Prometheus                  Following clues to the origin of mankind, a te...
# ...

# %% [markdown]
# 6 List all movies having runtime of 120 and above

# %%
movies = movies_df.loc[movies_df['Runtime (Minutes)'] >= 120]
movies
# Out:
#                          Rank                       Genre  \
# Title
# Guardians of the Galaxy     1     Action,Adventure,Sci-Fi
# Prometheus                  2    Adventure,Mystery,Sci-Fi
# Suicide Squad               5    Action,Adventure,Fantasy
# La La Land                  7          Comedy,Drama,Music
# The Lost City of Z          9  Action,Adventure,Biography
# ...                       ...                         ...
# Queen of Katwe            975       Biography,Drama,Sport
# The Skin I Live In        980              Drama,Thriller
# Across the Universe       983       Drama,Fantasy,Musical
# Selma                     990     Biography,Drama,History
# Taare Zameen Par          992          Drama,Family,Music
#
#                                                                Description  \
# Title
# Guardians of the Galaxy  A group of intergalactic criminals are forced ...
# Prometheus               Following clues to the origin of mankind, a te...
# ...

# %% [markdown]
# 7- List all movies having rating above 6

# %%
movies = movies_df.loc[movies_df['Rating'] >= 6]
movies
# Out:
#                          Rank                     Genre  \
# Title
# Guardians of the Galaxy     1   Action,Adventure,Sci-Fi
# Prometheus                  2  Adventure,Mystery,Sci-Fi
# Split                       3           Horror,Thriller
# Sing                        4   Animation,Comedy,Family
# Suicide Squad               5  Action,Adventure,Fantasy
# ...                       ...                       ...
# Taare Zameen Par          992        Drama,Family,Music
# Take Me Home Tonight      993      Comedy,Drama,Romance
# Project X                 995                    Comedy
# Secret in Their Eyes      996       Crime,Drama,Mystery
# Step Up 2: The Streets    998       Drama,Music,Romance
#
#                                                                Description  \
# Title
# Guardians of the Galaxy  A group of intergalactic criminals are forced ...
# Prometheus               Following clues to the origin of mankind, a te...
# ...

# %% [markdown]
# 8 List all movies having metascore above 50

# %%
movies = movies_df.loc[movies_df['Metascore'] > 50]
movies
# Out:
#                          Rank                     Genre  \
# Title
# Guardians of the Galaxy     1   Action,Adventure,Sci-Fi
# Prometheus                  2  Adventure,Mystery,Sci-Fi
# Split                       3           Horror,Thriller
# Sing                        4   Animation,Comedy,Family
# La La Land                  7        Comedy,Drama,Music
# ...                       ...                       ...
# Scream 4                  974            Horror,Mystery
# Queen of Katwe            975     Biography,Drama,Sport
# The Skin I Live In        980            Drama,Thriller
# Across the Universe       983     Drama,Fantasy,Musical
# Martyrs                   989                    Horror
#
#                                                                Description  \
# Title
# Guardians of the Galaxy  A group of intergalactic criminals are forced ...
# Prometheus               Following clues to the origin of mankind, a te...
# ...

# %% [markdown]
# 9- List all movies having metascore above 60 and ratings above 6 and year 2016

# %%
movies = movies_df.loc[(movies_df['Metascore'] > 60) & (movies_df['Rating'] > 6) & (movies_df['Year'] == 2016)]
movies
# Out:
#                                          Rank                       Genre  \
# Title
# Split                                       3             Horror,Thriller
# La La Land                                  7          Comedy,Drama,Music
# Mindhorn                                    8                      Comedy
# The Lost City of Z                          9  Action,Adventure,Biography
# Fantastic Beasts and Where to Find Them    11    Adventure,Family,Fantasy
# ...                                       ...                         ...
# The Siege of Jadotville                   939       Action,Drama,Thriller
# Kicks                                     950                   Adventure
# Custody                                   965                       Drama
# L'odyssée                                 967         Adventure,Biography
# Queen of Katwe                            975       Biography,Drama,Sport
#
# ...

# %%
movies = movies_df.loc[((movies_df['Director'] == 'David Yates') | (movies_df['Director'] == 'Adam Mckay')) & (movies_df['Rating'] > 6)]
movies.tail()
# Out:
#                                               Rank                     Genre  \
# Title
# The Legend of Tarzan                           108    Action,Adventure,Drama
# Harry Potter and the Deathly Hallows: Part 2   115   Adventure,Drama,Fantasy
# Harry Potter and the Order of the Phoenix      315  Adventure,Family,Fantasy
# Harry Potter and the Deathly Hallows: Part 1   419  Adventure,Family,Fantasy
# Harry Potter and the Half-Blood Prince         474  Adventure,Family,Fantasy
#
#                                                                                     Description  \
# Title
# The Legend of Tarzan                          Tarzan, having acclimated to life in London, i...
# Harry Potter and the Deathly Hallows: Part 2  Harry, Ron and Hermione search for Voldemort's...
# Harry Potter and the Order of the Phoenix     With their warning about Lord Voldemort's retu...
# Harry Potter and the Deathly Hallows: Part 1  As Harry races against time and evil to destro...
# ...

# %% [markdown]
# 11- List the movie which has highest rating in 2016 (Hint: solve in two steps, first filter the data of 2016
# and save in another variable and then filter the highest rating from that)

# %%
movies = movies_df.loc[movies_df['Year'] == 2016]
movies = movies_2012.sort_values(by='Rating', ascending=False)

movies
# Out:
#                          Rank                    Genre  \
# Title
# Dangal                    118   Action,Biography,Drama
# Kimi no na wa              97  Animation,Drama,Fantasy
# Koe no katachi            862  Animation,Drama,Romance
# La La Land                  7       Comedy,Drama,Music
# Paint It Black            479                    Drama
# ...                       ...                      ...
# Satanic                   270                   Horror
# The Last Face              50                    Drama
# The Intent                891              Crime,Drama
# Tall Men                  648  Fantasy,Horror,Thriller
# Don't Fuck in the Woods    43                   Horror
#
#                                                                Description  \
# Title
# Dangal                   Former wrestler Mahavir Singh Phogat and his t...
# Kimi no na wa            Two strangers find themselves linked in a biza...
# ...

# %% [markdown]
# 12- List the movie which has highest metascore in 2016 (Hint: solve in two steps, first filter the data of
# 2016 and save in another variable and then filter the highest metascore from that)

# %%
movies = movies_df.loc[movies_df['Year'] == 2016]
movies = movies_2012.sort_values(by='Metascore', ascending=False)

movies
# Out:
#                        Rank                   Genre  \
# Title
# Moonlight                42                   Drama
# Manchester by the Sea    22                   Drama
# Toni Erdmann            612            Comedy,Drama
# La La Land                7      Comedy,Drama,Music
# Paterson                208    Comedy,Drama,Romance
# ...                     ...                     ...
# American Pastoral       540             Crime,Drama
# Handsome Devil          606                   Drama
# Free State of Jones     618  Action,Biography,Drama
# The Whole Truth         629     Crime,Drama,Mystery
# Chalk It Up             779                  Comedy
#
#                                                              Description  \
# Title
# Moonlight              A chronicle of the childhood, adolescence and ...
# Manchester by the Sea  A depressed uncle is asked to take care of his...
# Toni Erdmann           A practical joking father tries to reconnect w...
# ...

# %% [markdown]
# 13- List the movie which has highest revenue in 2016 (Hint: solve in two steps, first filter the data of
# 2016 and save in another variable and then filter the highest revenue from that)

# %%
movies = movies_df.loc[movies_df['Year'] == 2016]
movies = movies.sort_values(by='Revenue (Millions)', ascending=False)

movies
# Out:
#                                 Rank                       Genre  \
# Title
# Rogue One                         13     Action,Adventure,Sci-Fi
# Finding Dory                     120  Animation,Adventure,Comedy
# Captain America: Civil War        36     Action,Adventure,Sci-Fi
# The Secret Life of Pets           16  Animation,Adventure,Comedy
# The Jungle Book                  126      Adventure,Drama,Family
# ...                              ...                         ...
# Transpecos                       943                    Thriller
# Custody                          965                       Drama
# L'odyssée                        967         Adventure,Biography
# Amateur Night                    978                      Comedy
# It's Only the End of the World   979                       Drama
#
#                                                                       Description  \
# Title
# Rogue One                       The Rebel Alliance makes a risky move to steal...
# ...

# %% [markdown]
# # t20.csv

# %% [markdown]
# 1- Load the t20 dataset

# %%
import pandas as pd
t20 = pd.read_csv("t20.csv")

# %%
t20
# Out:
#       Sno                   Player       Span  Mat  Inns  NO  Runs   HS  \
# 0       0          V Kohli (INDIA)  2010-2019   75    70  20  2633  94*
# 1       1        RG Sharma (INDIA)  2007-2019  104    96  14  2633  118
# 2       2          MJ Guptill (NZ)  2009-2019   83    80   7  2436  105
# 3       3   Shoaib Malik (ICC/PAK)  2006-2019  111   104  30  2263   75
# 4       4         BB McCullum (NZ)  2005-2015   71    70  10  2140  123
# ...   ...                      ...        ...  ...   ...  ..   ...  ...
# 1849   49        H Ssenyondo (UGA)  2019-2019    4     1   1     0   0*
# 1850    0     Taijul Islam (BDESH)  2019-2019    2     1   1     0   0*
# 1851    1       Ziaur Rehman (Fin)  2019-2019    1     1   0     0    0
# 1852    2           M Zondeki (SA)  2006-2006    1     1   0     0    0
# 1853    3  Zulqarnain Haider (ESP)  2019-2019    5     1   0     0    0
#
#         Ave    BF      SR  100  50  0   4s   6s  Unnamed: 15
# ...

# %% [markdown]
# 2- check the columns and values

# %%
t20.head()
# Out:
#    Sno                  Player       Span  Mat  Inns  NO  Runs   HS    Ave  \
# 0    0         V Kohli (INDIA)  2010-2019   75    70  20  2633  94*  52.66
# 1    1       RG Sharma (INDIA)  2007-2019  104    96  14  2633  118   32.1
# 2    2         MJ Guptill (NZ)  2009-2019   83    80   7  2436  105  33.36
# 3    3  Shoaib Malik (ICC/PAK)  2006-2019  111   104  30  2263   75  30.58
# 4    4        BB McCullum (NZ)  2005-2015   71    70  10  2140  123  35.66
#
#      BF      SR  100  50  0   4s   6s  Unnamed: 15
# 0  1907  138.07    0  24  2  247   71          NaN
# 1  1905  138.21    4  19  6  234  120          NaN
# 2  1810  134.58    2  15  2  215  113          NaN
# 3  1824  124.06    0   7  1  186   61          NaN
# 4  1571  136.21    2  13  3  199   91          NaN

# %%
t20.columns
# Out:
# Index(['Sno', 'Player', 'Span', 'Mat', 'Inns', 'NO', 'Runs', 'HS', 'Ave', 'BF',
#        'SR', '100', '50', '0', '4s', '6s', 'Unnamed: 15'],
#       dtype='object')

# %%
t20.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1854 entries, 0 to 1853
# Data columns (total 17 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Sno          1854 non-null   int64
#  1   Player       1854 non-null   object
#  2   Span         1854 non-null   object
#  3   Mat          1854 non-null   int64
#  4   Inns         1854 non-null   int64
#  5   NO           1854 non-null   int64
#  6   Runs         1854 non-null   int64
#  7   HS           1854 non-null   object
#  8   Ave          1854 non-null   object
#  9   BF           1854 non-null   int64
#  10  SR           1854 non-null   object
#  11  100          1854 non-null   int64
#  12  50           1854 non-null   int64
#  13  0            1854 non-null   int64
#  14  4s           1854 non-null   int64
#  15  6s           1854 non-null   int64
#  16  Unnamed: 15  0 non-null      float64
# dtypes: float64(1), int64(11), object(5)
# memory usage: 246.4+ KB

# %%
t20.describe()
# Out:
#                Sno          Mat         Inns           NO         Runs  \
# count  1854.000000  1854.000000  1854.000000  1854.000000  1854.000000
# mean     24.450378    11.981661     8.881877     1.902913   144.573894
# std      14.458735    15.274276    13.162506     3.028247   305.231238
# min       0.000000     1.000000     1.000000     0.000000     0.000000
# 25%      12.000000     3.000000     2.000000     0.000000     9.000000
# 50%      24.000000     6.000000     4.000000     1.000000    37.000000
# 75%      37.000000    14.000000    10.000000     2.000000   123.000000
# max      49.000000   111.000000   104.000000    42.000000  2633.000000
#
#                 BF          100           50            0           4s  \
# count  1854.000000  1854.000000  1854.000000  1854.000000  1854.000000
# mean    121.686084     0.029666     0.571197     0.816613    12.359223
# std     236.107498     0.219611     1.798258     1.292522    28.259788
# ...

# %%
t20['Sno'].value_counts()
# Out:
# 0     38
# 3     38
# 1     38
# 2     38
# 37    37
# 28    37
# 29    37
# 30    37
# 31    37
# 32    37
# 33    37
# 34    37
# 35    37
# 36    37
# 38    37
# 48    37
# 27    37
# 40    37
# 41    37
# 42    37
# 43    37
# 44    37
# 45    37
# 46    37
# 47    37
# 39    37
# 25    37
# 26    37
# 13    37
# 4     37
# 5     37
# 6     37
# 7     37
# 8     37
# 9     37
# 10    37
# 11    37
# 12    37
# 14    37
# 24    37
# 15    37
# 16    37
# 17    37
# 18    37
# 19    37
# 20    37
# 21    37
# 22    37
# 23    37
# 49    37
# Name: Sno, dtype: int64

# %% [markdown]
# 3- Drop column Unnamed: 15

# %%
t20.drop('Unnamed: 15', axis=1, inplace = True)

# %% [markdown]
# 4- Drop column Sno

# %%
t20.drop('Sno', axis=1, inplace = True)

# %%
t20.columns
# Out:
# Index(['Player', 'Span', 'Mat', 'Inns', 'NO', 'Runs', 'HS', 'Ave', 'BF', 'SR',
#        '100', '50', '0', '4s', '6s'],
#       dtype='object')

# %% [markdown]
# 5- Select all players who have more then 3 hundreds

# %%
t20.loc[t20['100'] > 3]
# Out:
#               Player       Span  Mat  Inns  NO  Runs   HS   Ave    BF      SR  \
# 1  RG Sharma (INDIA)  2007-2019  104    96  14  2633  118  32.1  1905  138.21
#
#    100  50  0   4s   6s
# 1    4  19  6  234  120

# %%
t20['100'].value_counts()
# Out:
# 0    1812
# 1      33
# 2       6
# 3       2
# 4       1
# Name: 100, dtype: int64

# %% [markdown]
# 6- Select all players who have highest score more then 50

# %%
t20['HS'].value_counts()
# Out:
# 0       59
# 1*      51
# 1       40
# 9       38
# 8       37
#         ..
# 99*      1
# 124      1
# 92*      1
# 109*     1
# 91*      1
# Name: HS, Length: 218, dtype: int64

# %%
t20str = t20.loc[t20['HS'].astype(str).str.replace('*', '').astype(int)> 50]
t20str
# Out:
# C:\Users\FYP-Administrator\AppData\Local\Temp\ipykernel_15816\3550095551.py:1: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   t20str = t20.loc[t20['HS'].astype(str).str.replace('*', '').astype(int)> 50]
#                      Player       Span  Mat  Inns  NO  Runs   HS    Ave    BF  \
# 0           V Kohli (INDIA)  2010-2019   75    70  20  2633  94*  52.66  1907
# 1         RG Sharma (INDIA)  2007-2019  104    96  14  2633  118   32.1  1905
# 2           MJ Guptill (NZ)  2009-2019   83    80   7  2436  105  33.36  1810
# 3    Shoaib Malik (ICC/PAK)  2006-2019  111   104  30  2263   75  30.58  1824
# 4          BB McCullum (NZ)  2005-2015   71    70  10  2140  123  35.66  1571
# ..                      ...        ...  ...   ...  ..   ...  ...    ...   ...
# ...

# %% [markdown]
# 7- How many players who have avg above 35?

# %%
t201= t20.loc[t20['Ave']!= '-']

# %%
t201[t201['Ave'].astype(float)>35 ]
# Out:
#                Player       Span  Mat  Inns  NO  Runs   HS    Ave    BF  \
# 0     V Kohli (INDIA)  2010-2019   75    70  20  2633  94*  52.66  1907
# 4    BB McCullum (NZ)  2005-2015   71    70  10  2140  123  35.66  1571
# 8      JP Duminy (SA)  2007-2019   81    75  25  1934  96*  38.68  1532
# 12     AJ Finch (AUS)  2011-2019   58    58   9  1878  172  38.32  1200
# 19   MS Dhoni (INDIA)  2006-2019   98    85  42  1617   56   37.6  1282
# ..                ...        ...  ...   ...  ..   ...  ...    ...   ...
# 877    KJ Young (Blz)  2019-2019    3     3   2    42  27*     42    34
# 884    B Mavuta (ZIM)  2018-2018    3     3   2    41   28     41    23
# 887      K Pala (PNG)  2015-2015    2     2   1    41  22*     41    30
# 915  D Mongia (INDIA)  2006-2006    1     1   0    38   38     38    45
# 928    D Manani (ROM)  2019-2019    2     2   1    37  19*     37    32
#
#          SR  100  50  0   4s  6s
# 0    138.07    0  24  2  247  71
# 4    136.21    2  13  3  199  91
# ...
